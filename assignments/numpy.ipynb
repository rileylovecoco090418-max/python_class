# %%
import numpy as np

# 1D Array
a = np.array([1, 2, 3])

# 2D Array (Matrix)
b = np.array([[1, 2], [3, 4]])

# %%
# Array of zeros
zeros = np.zeros((2, 3))

# Linear spacing
# (start, stop, num_elements)
lin = np.linspace(0, 10, 5)
