# %% [markdown]
# # Plotting Histogram in Python using Matplotlib
#
# Histograms are one of the most fundamental tools in data visualization. They provide a graphical representation of data distribution, showing how frequently each value or range of values occurs. Histograms are especially useful for analyzing continuous numerical data, such as measurements, sensor readings, or experimental results.
#
# A histogram is a type of bar plot where:
# - The **X-axis** represents intervals (called **bins**) of the data.
# - The **Y-axis** represents the frequency of values within each bin.

# %% [markdown]
# ## Matplotlib Histogram Parameters
#
# The `matplotlib.pyplot.hist()` function accepts several parameters for customization:
#
# | Attribute | Parameter |
# | :--- | :--- |
# | **x** | An array or sequence of numerical data. |
# | **bins** | Number of bins (int) or specific intervals (array). |
# | **density** | If True, normalizes the histogram to show probability instead of frequency. |
# | **range** | A tuple specifying lower and upper limits of bins. |
# | **histtype** | Type of histogram: `bar`, `barstacked`, `step`, `stepfilled`. Default: `bar`. |
# | **align** | Bin alignment: `left`, `right`, `mid`. |
# | **weights** | An array of weights for each data point. |
# | **bottom** | Baseline for bins. |
# | **rwidth** | Relative width of bars (0–1). |
# | **color** | Color of bars. Can be a single color or sequence. |
# | **label** | Label for legend. |
# | **log** | If True, uses logarithmic scale on Y-axis. |

# %% [markdown]
# ## 1. Basic Histogram
# The simplest way to visualize data distribution using a standard normal distribution.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data for the histogram
data = np.random.randn(1000)

# Plotting a basic histogram
plt.hist(data, bins=30, color='skyblue', edgecolor='black')

# Adding labels and title
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Basic Histogram')

# Display the plot
plt.show()

# %% [markdown]
# ## 2. Customized Histogram with Density Plot
# Using Seaborn to add a Kernel Density Estimate (KDE) curve over the histogram.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Generate random data
data = np.random.randn(1000)

# Creating a customized histogram with a density plot
sns.histplot(data, bins=30, kde=True, color='lightgreen', edgecolor='red')

plt.xlabel('Values')
plt.ylabel('Density')
plt.title('Customized Histogram with Density Plot')
plt.show()

# %% [markdown]
# ## 3. Customized Histogram with Watermark and Gradient
# An advanced example showing how to apply color gradients to bins and add text watermarks.

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors

# Creating dataset
np.random.seed(23685752)
N_points = 10000
n_bins = 20
x = np.random.randn(N_points)

# Creating figure and axes
fig, axs = plt.subplots(1, 1, figsize=(10, 7), tight_layout=True)

# Add x, y gridlines
axs.grid(visible=True, color='grey', linestyle='-.', linewidth=0.5, alpha=0.6)

# Add text watermark
fig.text(0.9, 0.15, 'GeeksforGeeks', fontsize=12, color='red', ha='right', va='bottom', alpha=0.7)

# Creating histogram and applying color gradient
N, bins, patches = axs.hist(x, bins=n_bins)
fracs = ((N ** (1 / 5)) / N.max())
norm = colors.Normalize(fracs.min(), fracs.max())

for thisfrac, thispatch in zip(fracs, patches):
    color = plt.cm.viridis(norm(thisfrac))
    thispatch.set_facecolor(color)

plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title('Customized Histogram with Watermark')
plt.show()

# %% [markdown]
# ## 4. Multiple Histograms with Subplots
# Comparing two different datasets side-by-side.

# %%
import matplotlib.pyplot as plt
import numpy as np

data1 = np.random.randn(1000)
data2 = np.random.normal(loc=3, scale=1, size=1000)

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))

axes[0].hist(data1, bins=30, color='Yellow', edgecolor='black')
axes[0].set_title('Histogram 1')

axes[1].hist(data2, bins=30, color='Pink', edgecolor='black')
axes[1].set_title('Histogram 2')

for ax in axes:
    ax.set_xlabel('Values')
    ax.set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Stacked Histogram
# Visualizing multiple datasets combined in a single plot.

# %%
import matplotlib.pyplot as plt
import numpy as np

data1 = np.random.randn(1000)
data2 = np.random.normal(loc=3, scale=1, size=1000)

plt.hist([data1, data2], bins=30, stacked=True, color=['cyan', 'Purple'], edgecolor='black')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Stacked Histogram')
plt.legend(['Dataset 1', 'Dataset 2'])
plt.show()

# %% [markdown]
# ## 6. 2D Histogram (Hexbin Plot)
# Visualizing density between two variables using hexagonal bins.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randn(1000)
y = 2 * x + np.random.normal(size=1000)

plt.hexbin(x, y, gridsize=30, cmap='Blues')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('2D Histogram (Hexbin Plot)')
plt.colorbar(label='Counts')
plt.show()
