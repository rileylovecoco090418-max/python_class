# %% [markdown]
# # Simple Plot in Python using Matplotlib
#
# Creating simple plots is a common step in data visualization. These visual representations help us to understand trends, patterns and relationships within data. **Matplotlib** is one of the most popular plotting libraries in Python which makes it easy to generate high-quality graphs with just a few lines of code.

# %% [markdown]
# ## Installation
# Before we start creating plots, we need to install Matplotlib. You can install it using the following command:

# %% [markdown]
# ## 1. Basic Example: Creating a Simple Plot
# Here is a basic example of creating a line plot using `plt.plot()`.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

plt.plot(x, y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Simple Plot')
plt.show()

# %% [markdown]
# ### Syntax and Parameters
# `plt.plot(x, y, format_string, **kwargs)`
#
# - **x**: A sequence of values for the x-axis.
# - **y**: A sequence of values for the y-axis.
# - **format_string**: (Optional) Specifies line style, color, and markers (e.g., `'ro--'` for red circles with dashed lines).
# - **kwargs**: Other optional parameters like `label`, `linewidth`, `markersize`, etc.

# %% [markdown]
# ## Key Matplotlib Functions
#
# | Method | Description |
# | :--- | :--- |
# | `plot()` | Creates a plot from given data. |
# | `show()` | Displays the created plot. |
# | `xlabel()`, `ylabel()` | Adds labels to the axes. |
# | `title()` | Adds a title to the plot. |
# | `legend()` | Adds a legend (useful for multiple series). |
# | `grid()` | Configures the grid lines. |
# | `subplot(r, c, i)` | Creates multiple subplots in a grid. |
# | `scatter()` | Creates a scatter plot. |

# %% [markdown]
# ## Example 1: Customized Line Plot with Multiple Series
# In this example, we'll create a line plot with two different functions: $y = x^2$ and $y = 30 - x^2$, with added customization.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y1 = [1, 4, 9, 16, 25]
y2 = [25, 20, 15, 10, 5]

plt.plot(x, y1, label='y = x^2', color='green', linestyle='--', marker='o')
plt.plot(x, y2, label='y = 30 - x^2', color='red', linestyle='-', marker='x')

plt.grid(True)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Customized Line Plot with Multiple Series')
plt.legend()
plt.show()

# %% [markdown]
# ## Example 2: Creating Multiple Subplots in One Figure
# We can create a grid of subplots (e.g., 2x2) to compare different datasets side-by-side.

# %%
import matplotlib.pyplot as plt

a = [1, 2, 3, 4, 5]
b = [0, 0.6, 0.2, 15, 10, 8, 16, 21]
c = [4, 2, 6, 8, 3, 20, 13, 15]

fig = plt.figure(figsize =(10, 10))

sub1 = plt.subplot(2, 2, 1)
sub2 = plt.subplot(2, 2, 2)
sub3 = plt.subplot(2, 2, 3)
sub4 = plt.subplot(2, 2, 4)

sub1.plot(a, 'sb')
sub1.set_xticks(list(range(0, 10, 1)))
sub1.set_title('1st Rep')

sub2.plot(b, 'or')
sub2.set_xticks(list(range(0, 10, 2)))
sub2.set_title('2nd Rep')

sub3.plot(list(range(0, 22, 3)), 'vg')
sub3.set_xticks(list(range(0, 10, 1)))
sub3.set_title('3rd Rep')

sub4.plot(c, 'Dm')
sub4.set_yticks(list(range(0, 24, 2)))
sub4.set_title('4th Rep')

plt.show()

# %% [markdown]
# ## Example 3: Plotting a Scatter Plot
# Scatter plots are used to visualize the relationship between two variables.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.scatter(x, y, color='blue', marker='x')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Simple Scatter Plot')
plt.show()
