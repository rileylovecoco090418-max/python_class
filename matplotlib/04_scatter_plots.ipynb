# %% [markdown]
# # Matplotlib Scatter Plot in Python
#
# Scatter plots are fundamental tools for visualizing relationships between two numerical variables. `matplotlib.pyplot.scatter()` plots points on a Cartesian plane defined by X and Y coordinates. Each point represents a data observation, allowing us to visually analyze correlations, clusters, or distributions.

# %% [markdown]
# ## Syntax & Parameters
#
# ### Syntax
# ```python
# matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, alpha=None, edgecolors=None, label=None)
# ```
#
# ### Parameters
# | Parameter | Description |
# | :--- | :--- |
# | **x, y** | Sequences of data points to plot. |
# | **s** | Marker size (scalar or array-like). |
# | **c** | Marker color (color name, hex, or array of values). |
# | **marker** | Shape of the marker (e.g., `'o'`, `'^'`, `'s'`). |
# | **cmap** | Colormap for mapping numeric values to colors. |
# | **alpha** | Transparency level (0 = transparent, 1 = opaque). |
# | **edgecolors** | Color of the marker edges. |
# | **label** | Legend label for the dataset. |
#
# ### Returns
# This function returns a **PathCollection** object. This object can be used to further customize the plot or to update it dynamically.

# %% [markdown]
# ## 1. Basic Scatter Plot
# A simple scatter plot using NumPy arrays for X and Y values.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([12, 45, 7, 32, 89, 54, 23, 67, 14, 91])
y = np.array([99, 31, 72, 56, 19, 88, 43, 61, 35, 77])

plt.scatter(x, y)
plt.title("Basic Scatter Plot")
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.show()

# %% [markdown]
# ## 2. Comparing Two Groups
# Using different colors and labels to distinguish between two datasets.

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([160, 165, 170, 175, 180, 185, 190, 195, 200, 205])
y1 = np.array([55, 58, 60, 62, 64, 66, 68, 70, 72, 74])
x2 = np.array([150, 155, 160, 165, 170, 175, 180, 195, 200, 205])
y2 = np.array([50, 52, 54, 56, 58, 64, 66, 68, 70, 72])

plt.scatter(x1, y1, color='blue', label='Group 1')
plt.scatter(x2, y2, color='red', label='Group 2')

plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.title('Comparison of Height vs Weight between two groups')
plt.legend()
plt.show()

# %% [markdown]
# ## 3. Customizing Sizes and Colors
# Demonstrating how to vary point size (`s`) and color (`c`) based on data arrays.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([3, 12, 9, 20, 5, 18, 22, 11, 27, 16])
y = np.array([95, 55, 63, 77, 89, 50, 41, 70, 58, 83])
sizes = [20, 50, 100, 200, 500, 1000, 60, 90, 150, 300] 
colors = ['red', 'green', 'blue', 'purple', 'orange', 'black', 'pink', 'brown', 'yellow', 'cyan'] 

plt.scatter(x, y, s=sizes, c=colors, alpha=0.6, edgecolors='w', linewidths=1)
plt.title("Scatter Plot with Varying Colors and Sizes")
plt.show()

# %% [markdown]
# ## 4. Bubble Plot
# A bubble plot is a scatter plot where point size represents a third variable.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]
sizes = [30, 80, 150, 200, 300] 

plt.scatter(x, y, s=sizes, alpha=0.5, edgecolors='blue', linewidths=2)
plt.title("Bubble Plot Example")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %% [markdown]
# ## 5. Colormap and Colorbar
# Mapping a third variable to color intensity using a colormap (`cmap`).

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(50, 150, 100)
y = np.random.randint(50, 150, 100)
colors = np.random.rand(100)
sizes = 20 * np.random.randint(10, 100, 100)

plt.scatter(x, y, c=colors, s=sizes, cmap='viridis', alpha=0.7)
plt.colorbar(label='Color scale')
plt.title("Scatter Plot with Colormap and Colorbar")
plt.show()

# %% [markdown]
# ## 6. Changing Marker Styles
# Customizing the shape of data points using the `marker` parameter.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.rand(10)
y = np.random.rand(10)

plt.scatter(x, y, marker='^', color='magenta', s=100, alpha=0.7)
plt.title("Scatter Plot with Triangle Markers")
plt.show()
