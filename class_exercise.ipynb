# %% [markdown]
# # Coding Exercise: University Management System (60 Mins)
#
# ## Scenario
# You have been tasked with building the core backend logic for a University Management System using Object-Oriented Programming in Python. You will build a system that manages people (Students and Professors), university accounts, and departmental structures.
#
# ---
#
# ## Instructions
#
# ### Task 1: Basic Structure & Inheritance (20 mins)
# 1. Create a base class named `Person`.
#    - It should have an `__init__` constructor that accepts `first_name` and `last_name`.
#    - Add a method called `get_full_name(self)` that returns the full name.
# 2. Create a child class named `Student` that inherits from `Person`.
#    - Use the `super()` function in its constructor to pass `first_name` and `last_name` to the parent class.
#    - The constructor should also accept and set an instance property: `graduation_year`.
#    - Add a method `introduce(self)` that returns: `"Hi, I am [Full Name], graduating in [Year]."`
# 3. Create another child class named `Professor` that inherits from `Person`.
#    - Use `super()` in its constructor.
#    - The constructor should also accept and set an instance property: `subject`.
#    - Add a method `introduce(self)` that returns: `"Hello, I am Professor [Full Name], teaching [Subject]."`
#
# ### Task 2: Polymorphism (10 mins)
# 1. Write a standalone function (outside of any class) called `introduce_all(people_list)`.
# 2. This function should accept a list containing `Student` and `Professor` objects, loop through them, and print the output of their respective `introduce()` methods.
#
# ### Task 3: Encapsulation & Data Validation (15 mins)
# 1. Create a class named `TuitionAccount`.
#    - The constructor should accept `student_name` (Public) and an initial `balance` (Private, using `__balance`).
#    - Create a Getter method `get_balance(self)` to safely view the balance.
#    - Create a Setter method `set_balance(self, amount)` that allows updating the balance **only if** the amount is greater than or equal to 0. If it is negative, print `"Invalid balance amount!"`.
#    - Add a public method `make_payment(self, amount)` that decreases the private balance, provided the payment amount is positive.
#
# ### Task 4: Inner Classes & Class Properties (15 mins)
# 1. Create a class named `University`.
#    - Add a **Class Property** named `uni_name` and set it to `"Tech Institute"`.
#    - The constructor should accept a `location`.
#    - Inside `University`, define an **Inner Class** named `Department`.
#      - The `Department` constructor should take a `dept_name` and set it as an instance variable.
#    - In the `University` constructor, instantiate the inner `Department` class with the name `"Computer Science"` and assign it to an instance variable `self.dept`.
#
# ---
#
# ## Test Execution Code
# At the bottom of your script, write execution code that proves everything works:
# 1. Instantiates a Student and a Professor, then passes them to `introduce_all()`.
# 2. Instantiates a `TuitionAccount`, tries to set a negative balance, updates it legally, makes a payment, and prints the balance using the getter.
# 3. Instantiates a `University` and prints both the class property `uni_name` and the inner department's name.
# 4. **Name Mangling Demonstration:** Write a line trying to print the private balance directly via `account.__balance` inside a `try/except AttributeError` block to prove it is hidden, then use name mangling (`account._TuitionAccount__balance`) to print it anyway.

# %% [markdown]
# ## TASK 1: Basic Structure & Inheritance

# %% [markdown]
# ## TASK 2: Polymorphism

# %% [markdown]
# ## TASK 3: Encapsulation & Data Validation

# %% [markdown]
# ## TASK 4: Inner Classes & Class Properties

# %% [markdown]
# # TEST EXECUTION

# %%
print("--- Testing Tasks 1 & 2: Inheritance & Polymorphism ---")
# 

print("--- Testing Task 3: Encapsulation & Validation ---")

print("--- Testing Task 3 Extra: Name Mangling Demo ---")
# try:
#     print(account.__balance)
# except AttributeError:
#     print("Caught expected AttributeError: Direct access to '__balance' is blocked.")
    
print("--- Testing Task 4: Class Property & Inner Class ---")
# Out:
# --- Testing Tasks 1 & 2: Inheritance & Polymorphism ---
# --- Testing Task 3: Encapsulation & Validation ---
# --- Testing Task 3 Extra: Name Mangling Demo ---
# --- Testing Task 4: Class Property & Inner Class ---
