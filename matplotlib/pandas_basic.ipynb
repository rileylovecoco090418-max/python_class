# %%
# block 1
import pandas as pd

# From a list
s = pd.Series([1, 3, 5, 7])

# With custom index
s = pd.Series([10, 20],
index=['a', 'b'])

# %%
# block 2
data = {
 'Name': ['Alice', 'Bob'],
 'Age': [25, 30]
 }
df = pd.DataFrame(data)
